# %% [markdown]
# # 最大子数组和（动态规划版）

# %% [markdown]
# ### 思路

# %% [markdown]
# 本题在之前我们使用Kadane算法解决过 在这里我们使用动态规划的思想解决

# %% [markdown]
# ### 代码

# %%
def maxSubArray(nums):
    dp = [0] * len(nums)
    dp[0] = nums[0]
    for i in range(1, len(nums)):
        if dp[i-1] < 0:
            dp[i] = nums[i]
        else:
            dp[i] = max(dp[i-1] + nums[i], nums[i])
    return max(dp)
nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
print(maxSubArray(nums))
# Out:
# 6

# %% [markdown]
# ### 类似问题（121. 最好买卖股票时机）

# %% [markdown]
# ### 思路

# %% [markdown]
# 本题在之前解决过 在这里使用动态规划重现一次

# %% [markdown]
# ### 代码

# %%
def maxProfit(prices):
    dp = [0] * len(prices)
    dp[0] = 0
    min_price = prices[0]
    for i in range(1, len(prices)):
        min_price = min(min_price, prices[i])
        dp[i] = max(dp[i-1], prices[i] - min_price)
    return max(dp)
prices = [7, 1, 5, 3, 6, 4]
print(maxProfit(prices))
# Out:
# 5
